# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.close("all")

# %%
ts= pd.Series(np.random.randn(1000), index = pd.date_range("1/1/2000", periods=1000))
ts.head()
ts.tail()
ts= ts.cumsum()
ts.plot()
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index = ts.index, columns=["A", "B", "C", "D"])
df = df.cumsum()
plt.figure();
df.plot();
plt.legend(loc='best');
df.head()
# Out:
#                    A         B         C         D
# 2000-01-01  0.789535 -0.528280 -0.089465  1.691695
# 2000-01-02  0.632877 -0.756093  0.719359  1.243172
# 2000-01-03 -0.507115  0.118961 -0.640584  1.497913
# 2000-01-04 -0.869077  0.281502 -1.584614  0.357005
# 2000-01-05  0.955517 -0.085995 -1.558644  0.498751

# %%
dates = pd.date_range("20100101", periods = 6)
dates
# Out:
# DatetimeIndex(['2010-01-01', '2010-01-02', '2010-01-03', '2010-01-04',
#                '2010-01-05', '2010-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df1 = pd.DataFrame(np.random.randn(6, 4), index = dates, columns=list("ABCD"))
df1
# Out:
#                    A         B         C         D
# 2010-01-01  1.542281 -0.664904 -0.559540  0.690973
# 2010-01-02 -0.482850  0.237608  1.090886  0.222942
# 2010-01-03  0.524901  0.389729  0.030428  0.038315
# 2010-01-04  0.375705 -2.549209  1.530420 -0.482693
# 2010-01-05  2.500249 -0.766971 -0.315821 -1.239658
# 2010-01-06  0.519399  0.995887 -1.581688  0.230838

# %%
df2 = pd.DataFrame(
{
    "A": 1.0,
    "B": pd.date_range('20130102', periods = 6),
    "C": pd.Series(1, index=list(range(6)), dtype="float32"),
    "D": np.array([3]*6, dtype= "int32"),
    "E": pd.Categorical(["test", "train", "test", "train","test", "train"]),
    "F": "foo"
})

df2
df2.describe()
df2.A
df2.abs
df2.add
df2.align
df2.all
df2.any
df2.boxplot()
df2.columns
df2.count()
df2.duplicated()
df2.diff
df2.clip()
df2.E
df2.index
df2.head()
df2.tail()
# Out:
#      A          B    C  D      E    F
# 1  1.0 2013-01-03  1.0  3  train  foo
# 2  1.0 2013-01-04  1.0  3   test  foo
# 3  1.0 2013-01-05  1.0  3  train  foo
# 4  1.0 2013-01-06  1.0  3   test  foo
# 5  1.0 2013-01-07  1.0  3  train  foo

# %%
df2.index
# Out:
# Int64Index([0, 1, 2, 3, 4, 5], dtype='int64')

# %%
df.index
# Out:
# DatetimeIndex(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04',
#                '2000-01-05', '2000-01-06', '2000-01-07', '2000-01-08',
#                '2000-01-09', '2000-01-10',
#                ...
#                '2002-09-17', '2002-09-18', '2002-09-19', '2002-09-20',
#                '2002-09-21', '2002-09-22', '2002-09-23', '2002-09-24',
#                '2002-09-25', '2002-09-26'],
#               dtype='datetime64[ns]', length=1000, freq='D')

# %%
df.to_numpy()
# Out:
# array([[  0.78953463,  -0.52827964,  -0.08946535,   1.69169533],
#        [  0.63287738,  -0.75609283,   0.71935948,   1.24317195],
#        [ -0.50711513,   0.11896102,  -0.64058442,   1.49791311],
#        ...,
#        [-22.42748803,  19.32258944,  11.3976367 ,  71.06217967],
#        [-22.67055368,  19.19754322,  11.41639903,  71.29491593],
#        [-24.02142773,  18.82065399,  12.23851436,  72.19261334]])

# %%
df2.to_numpy()
# Out:
# array([[1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-03 00:00:00'), 1.0, 3, 'train', 'foo'],
#        [1.0, Timestamp('2013-01-04 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-05 00:00:00'), 1.0, 3, 'train', 'foo'],
#        [1.0, Timestamp('2013-01-06 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-07 00:00:00'), 1.0, 3, 'train', 'foo']],
#       dtype=object)

# %%
df2.describe()
# Out:
#          A    C    D
# count  6.0  6.0  6.0
# mean   1.0  1.0  3.0
# std    0.0  0.0  0.0
# min    1.0  1.0  3.0
# 25%    1.0  1.0  3.0
# 50%    1.0  1.0  3.0
# 75%    1.0  1.0  3.0
# max    1.0  1.0  3.0

# %%
df.T
# Out:
#    2000-01-01  2000-01-02  2000-01-03  2000-01-04  2000-01-05  2000-01-06  \
# A    0.789535    0.632877   -0.507115   -0.869077    0.955517   -0.004391
# B   -0.528280   -0.756093    0.118961    0.281502   -0.085995    0.474966
# C   -0.089465    0.719359   -0.640584   -1.584614   -1.558644   -0.849322
# D    1.691695    1.243172    1.497913    0.357005    0.498751   -0.979367
#
#    2000-01-07  2000-01-08  2000-01-09  2000-01-10  ...  2002-09-17  \
# A    0.155785   -1.042307   -1.174611   -0.356602  ...  -26.558868
# B    0.203654    0.272527    0.778379    0.106864  ...   23.665388
# C    0.371548    0.926344    0.203271    1.533318  ...   12.462477
# D   -1.105397   -2.468534   -1.788709   -0.930127  ...   74.672640
#
#    2002-09-18  2002-09-19  2002-09-20  2002-09-21  2002-09-22  2002-09-23  \
# A  -26.208876  -26.577150  -27.242498  -26.331189  -24.082486  -23.255538
# B   22.097358   21.539555   21.527798   20.234234   19.855948   19.597067
# C   12.250190   12.559770   12.049892   12.563377   12.277071   11.310634
# D   74.533377   75.205629   75.863577   76.073673   75.236098   74.030739
#
#    2002-09-24  2002-09-25  2002-09-26
# A  -22.427488  -22.670554  -24.021428
# B   19.322589   19.197543   18.820654
# C   11.397637   11.416399   12.238514
# D   71.062180   71.294916   72.192613
#
# [4 rows x 1000 columns]

# %%
df2.T
# Out:
#                      0                    1                    2  \
# A                  1.0                  1.0                  1.0
# B  2013-01-02 00:00:00  2013-01-03 00:00:00  2013-01-04 00:00:00
# C                  1.0                  1.0                  1.0
# D                    3                    3                    3
# E                 test                train                 test
# F                  foo                  foo                  foo
#
#                      3                    4                    5
# A                  1.0                  1.0                  1.0
# B  2013-01-05 00:00:00  2013-01-06 00:00:00  2013-01-07 00:00:00
# C                  1.0                  1.0                  1.0
# D                    3                    3                    3
# E                train                 test                train
# F                  foo                  foo                  foo

# %%
df
# Out:
#                     A          B          C          D
# 2000-01-01   0.789535  -0.528280  -0.089465   1.691695
# 2000-01-02   0.632877  -0.756093   0.719359   1.243172
# 2000-01-03  -0.507115   0.118961  -0.640584   1.497913
# 2000-01-04  -0.869077   0.281502  -1.584614   0.357005
# 2000-01-05   0.955517  -0.085995  -1.558644   0.498751
# ...               ...        ...        ...        ...
# 2002-09-22 -24.082486  19.855948  12.277071  75.236098
# 2002-09-23 -23.255538  19.597067  11.310634  74.030739
# 2002-09-24 -22.427488  19.322589  11.397637  71.062180
# 2002-09-25 -22.670554  19.197543  11.416399  71.294916
# 2002-09-26 -24.021428  18.820654  12.238514  72.192613
#
# [1000 rows x 4 columns]

# %%
df.describe()
# Out:
#                  A            B            C            D
# count  1000.000000  1000.000000  1000.000000  1000.000000
# mean    -17.665649    -6.475996     5.904269    39.979514
# std      10.359007    19.089184     9.844705    18.301790
# min     -47.974607   -39.564460   -17.657715    -2.468534
# 25%     -24.084361   -25.896575    -0.143993    27.879386
# 50%     -17.610346    -4.728107     8.160044    36.212890
# 75%      -9.695850     8.898821    12.945721    54.403942
# max       2.326647    26.611334    27.033556    76.073673

# %%
df.sort_index(axis=1, ascending = False)
# Out:
#                     D          C          B          A
# 2000-01-01   1.691695  -0.089465  -0.528280   0.789535
# 2000-01-02   1.243172   0.719359  -0.756093   0.632877
# 2000-01-03   1.497913  -0.640584   0.118961  -0.507115
# 2000-01-04   0.357005  -1.584614   0.281502  -0.869077
# 2000-01-05   0.498751  -1.558644  -0.085995   0.955517
# ...               ...        ...        ...        ...
# 2002-09-22  75.236098  12.277071  19.855948 -24.082486
# 2002-09-23  74.030739  11.310634  19.597067 -23.255538
# 2002-09-24  71.062180  11.397637  19.322589 -22.427488
# 2002-09-25  71.294916  11.416399  19.197543 -22.670554
# 2002-09-26  72.192613  12.238514  18.820654 -24.021428
#
# [1000 rows x 4 columns]

# %%
df.sort_index(axis=1, ascending=True)
# Out:
#                     A          B          C          D
# 2000-01-01   0.789535  -0.528280  -0.089465   1.691695
# 2000-01-02   0.632877  -0.756093   0.719359   1.243172
# 2000-01-03  -0.507115   0.118961  -0.640584   1.497913
# 2000-01-04  -0.869077   0.281502  -1.584614   0.357005
# 2000-01-05   0.955517  -0.085995  -1.558644   0.498751
# ...               ...        ...        ...        ...
# 2002-09-22 -24.082486  19.855948  12.277071  75.236098
# 2002-09-23 -23.255538  19.597067  11.310634  74.030739
# 2002-09-24 -22.427488  19.322589  11.397637  71.062180
# 2002-09-25 -22.670554  19.197543  11.416399  71.294916
# 2002-09-26 -24.021428  18.820654  12.238514  72.192613
#
# [1000 rows x 4 columns]

# %%
df.sort_values(by="B")
# Out:
#                     A          B         C          D
# 2000-08-24 -36.013074 -39.564460  8.677615  34.616206
# 2000-08-19 -31.261328 -39.334645  9.237520  32.915483
# 2000-08-21 -32.923518 -38.931524  9.509735  34.114563
# 2000-08-22 -33.881576 -38.891536  8.777956  33.432749
# 2000-08-20 -32.068622 -38.679637  9.607517  33.328626
# ...               ...        ...       ...        ...
# 2002-06-10 -23.631568  25.594960  6.956060  68.955620
# 2002-06-09 -24.195697  25.857159  6.950400  69.773824
# 2002-06-08 -24.961067  25.930369  5.964468  70.104430
# 2002-06-12 -24.076986  26.488463  7.446124  70.328007
# 2002-06-11 -23.569664  26.611334  7.672799  69.427889
#
# [1000 rows x 4 columns]

# %%
df.sort_values(by="A")
# Out:
#                     A          B          C          D
# 2000-09-19 -47.974607 -33.937008  16.163011  26.978587
# 2000-09-20 -47.524301 -33.128952  16.088898  28.926595
# 2000-09-29 -46.768449 -32.792762  14.228329  37.862107
# 2000-09-18 -46.699157 -33.537778  16.710731  28.125288
# 2000-09-28 -46.543996 -32.722868  15.373724  35.064996
# ...               ...        ...        ...        ...
# 2000-02-06   1.452889  -7.270907   2.816133   0.222764
# 2000-01-28   1.519367  -6.104965   5.899964   0.391039
# 2000-02-05   1.641217  -7.680984   1.330252   1.322077
# 2000-01-26   1.779449  -5.464987   3.754682   0.366440
# 2000-01-27   2.326647  -7.045704   4.528710   0.646271
#
# [1000 rows x 4 columns]

# %%
df["A"].head()
# Out:
# 2000-01-01    0.789535
# 2000-01-02    0.632877
# 2000-01-03   -0.507115
# 2000-01-04   -0.869077
# 2000-01-05    0.955517
# Freq: D, Name: A, dtype: float64

# %%
df["B"]
# Out:
# 2000-01-01    -0.528280
# 2000-01-02    -0.756093
# 2000-01-03     0.118961
# 2000-01-04     0.281502
# 2000-01-05    -0.085995
#                 ...
# 2002-09-22    19.855948
# 2002-09-23    19.597067
# 2002-09-24    19.322589
# 2002-09-25    19.197543
# 2002-09-26    18.820654
# Freq: D, Name: B, Length: 1000, dtype: float64

# %%
df[0:10]
# Out:
#                    A         B         C         D
# 2000-01-01  0.789535 -0.528280 -0.089465  1.691695
# 2000-01-02  0.632877 -0.756093  0.719359  1.243172
# 2000-01-03 -0.507115  0.118961 -0.640584  1.497913
# 2000-01-04 -0.869077  0.281502 -1.584614  0.357005
# 2000-01-05  0.955517 -0.085995 -1.558644  0.498751
# 2000-01-06 -0.004391  0.474966 -0.849322 -0.979367
# 2000-01-07  0.155785  0.203654  0.371548 -1.105397
# 2000-01-08 -1.042307  0.272527  0.926344 -2.468534
# 2000-01-09 -1.174611  0.778379  0.203271 -1.788709
# 2000-01-10 -0.356602  0.106864  1.533318 -0.930127

# %%
df[["A", "B","C"]]
# Out:
#                     A          B          C
# 2000-01-01   0.789535  -0.528280  -0.089465
# 2000-01-02   0.632877  -0.756093   0.719359
# 2000-01-03  -0.507115   0.118961  -0.640584
# 2000-01-04  -0.869077   0.281502  -1.584614
# 2000-01-05   0.955517  -0.085995  -1.558644
# ...               ...        ...        ...
# 2002-09-22 -24.082486  19.855948  12.277071
# 2002-09-23 -23.255538  19.597067  11.310634
# 2002-09-24 -22.427488  19.322589  11.397637
# 2002-09-25 -22.670554  19.197543  11.416399
# 2002-09-26 -24.021428  18.820654  12.238514
#
# [1000 rows x 3 columns]

# %%
dates
# Out:
# DatetimeIndex(['2010-01-01', '2010-01-02', '2010-01-03', '2010-01-04',
#                '2010-01-05', '2010-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.iloc[3:6, :]
# Out:
#                    A         B         C         D
# 2000-01-04 -0.869077  0.281502 -1.584614  0.357005
# 2000-01-05  0.955517 -0.085995 -1.558644  0.498751
# 2000-01-06 -0.004391  0.474966 -0.849322 -0.979367

# %%
df.iloc[:10, 1:3]
# Out:
#                    B         C
# 2000-01-01 -0.528280 -0.089465
# 2000-01-02 -0.756093  0.719359
# 2000-01-03  0.118961 -0.640584
# 2000-01-04  0.281502 -1.584614
# 2000-01-05 -0.085995 -1.558644
# 2000-01-06  0.474966 -0.849322
# 2000-01-07  0.203654  0.371548
# 2000-01-08  0.272527  0.926344
# 2000-01-09  0.778379  0.203271
# 2000-01-10  0.106864  1.533318

# %%
df.iat[1,1]
# Out:
# -0.7560928274918497

# %%
df.iloc[1,1]
# Out:
# -0.7560928274918497

# %%
df[df[["A", "B", "C"]]>0]
# Out:
#                    A          B          C   D
# 2000-01-01  0.789535        NaN        NaN NaN
# 2000-01-02  0.632877        NaN   0.719359 NaN
# 2000-01-03       NaN   0.118961        NaN NaN
# 2000-01-04       NaN   0.281502        NaN NaN
# 2000-01-05  0.955517        NaN        NaN NaN
# ...              ...        ...        ...  ..
# 2002-09-22       NaN  19.855948  12.277071 NaN
# 2002-09-23       NaN  19.597067  11.310634 NaN
# 2002-09-24       NaN  19.322589  11.397637 NaN
# 2002-09-25       NaN  19.197543  11.416399 NaN
# 2002-09-26       NaN  18.820654  12.238514 NaN
#
# [1000 rows x 4 columns]

# %%
df3 = df.copy()
exit()

# %% [markdown]
# ## Air Quality

# %%
air_q = pd.read_csv
